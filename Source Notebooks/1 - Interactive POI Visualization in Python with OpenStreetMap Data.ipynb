# %%
import osmnx as ox
import geopandas as gpd
import folium
print(ox.__version__)
# Out:
# 2.1.0

# %%
city_name = "Budapest"
admin = ox.geocode_to_gdf(city_name)
admin.plot()
# Out:
# <Axes: >

# %%
pubs = ox.features_from_place(city_name, {"amenity": "pub"})
sports = ox.features_from_place(city_name, {"leisure": ["gym", "sports_centre"]})
healthcare = ox.features_from_place(city_name, {"amenity": ["hospital", "clinic", "doctors", "pharmacy"]})

print("Pubs:", len(pubs), " | Sports:", len(sports), " | Healthcare:", len(healthcare))
# Out:
# Pubs: 665  | Sports: 322  | Healthcare: 969

# %%
def to_points(gdf):
    if gdf.empty:
        return gdf
    return gdf.to_crs(3857).centroid.to_crs(4326).to_frame("geometry")

pubs = to_points(pubs)
sports = to_points(sports)
healthcare = to_points(healthcare)

# %%
minx, miny, maxx, maxy = admin.total_bounds
fit_bounds = [[miny, minx], [maxy, maxx]]
center = [(miny + maxy) / 2, (minx + maxx) / 2]

# %%
m = folium.Map(
    location=center,
    tiles="CartoDB dark_matter",
    control_scale=True
)

admin_layer = folium.FeatureGroup(name="Admin Boundary", show=True)

folium.GeoJson(
    admin,
    style_function=lambda feature: {
        "fillColor": "#ffffff",
        "color": "#ffffff",
        "weight": 3,
        "fillOpacity": 0.15
    }
).add_to(admin_layer)

admin_layer.add_to(m)

folium.LayerControl(collapsed=False, position="topright").add_to(m)

if fit_bounds:
    m.fit_bounds(fit_bounds)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59bdf452dcf04a9c964cf424e3eefb42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59bdf452dcf04a9c964cf424e3eefb42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59bdf452dcf04a9c964cf424e3eefb42 = L.map(
#                 &quot;map_59bdf452dcf04a9c964cf424e3eefb42&quot;,
#                 {
#                     center: [47.48141835, 19.13001575],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_59bdf452dcf04a9c964cf424e3eefb42);
#
#
#
#
#
#             var tile_layer_1e317dc1cb8bd3d04943985df59bb7f1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e317dc1cb8bd3d04943985df59bb7f1.addTo(map_59bdf452dcf04a9c964cf424e3eefb42);
#
#
#             var feature_group_2af67f0de9425a0e44edf43055289cca = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_33d63ac6984d975e00bab88de101b7f4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#ffffff&quot;, &quot;fillColor&quot;: &quot;#ffffff&quot;, &quot;fillOpacity&quot;: 0.15, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_33d63ac6984d975e00bab88de101b7f4_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_33d63ac6984d975e00bab88de101b7f4 = L.geoJson(null, {
#                 onEachFeature: geo_json_33d63ac6984d975e00bab88de101b7f4_onEachFeature,
#
#                 style: geo_json_33d63ac6984d975e00bab88de101b7f4_styler,
#             ...{
# }
#         });
#
#         function geo_json_33d63ac6984d975e00bab88de101b7f4_add (data) {
#             geo_json_33d63ac6984d975e00bab88de101b7f4
#                 .addData(data);
#         }
#             geo_json_33d63ac6984d975e00bab88de101b7f4_add({&quot;bbox&quot;: [18.9251057, 47.3496899, 19.3349258, 47.6131468], &quot;features&quot;: [{&quot;bbox&quot;: [18.9251057, 47.3496899, 19.3349258, 47.6131468], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[18
admin_layer = folium.FeatureGroup(name="Admin Boundary", show=True)

pubs_layer = folium.FeatureGroup(name="Pubs", show=True)
sports_layer = folium.FeatureGroup(name="Gyms & Sports", show=True)
health_layer = folium.FeatureGroup(name="Healthcare", show=False)


folium.GeoJson(
    admin,
    style_function=lambda feature: {
        "fillColor": "#ffffff",
        "color": "#ffffff",
        "weight": 3,
        "fillOpacity": 0.15
    }
).add_to(admin_layer)


def add_points(gdf, feature_group, color):
    if gdf is not None and not gdf.empty:
        for _, row in gdf.iterrows():
            geom = row.geometry
            if geom is None:
                continue
            lat, lon = geom.y, geom.x
            folium.CircleMarker(
                location=[lat, lon],
                radius=2,
                weight=0.5,
                fill=True,
                fill_opacity=0.8,
                color=color,
                fill_color=color,
                # tooltip removed as requested
            ).add_to(feature_group)


add_points(pubs, pubs_layer, "#ff9933")     # orange
add_points(sports, sports_layer, "#44e0ff") # cyan
add_points(healthcare, health_layer, "#ff4444") # red


admin_layer.add_to(m)
pubs_layer.add_to(m)
sports_layer.add_to(m)
health_layer.add_to(m)


folium.LayerControl(collapsed=False, position="topright").add_to(m)

if fit_bounds:
    m.fit_bounds(fit_bounds)

m.save("budapest_pubs.html")


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a56108e6cd65e7d91a2580ea4a3c047 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a56108e6cd65e7d91a2580ea4a3c047&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a56108e6cd65e7d91a2580ea4a3c047 = L.map(
#                 &quot;map_0a56108e6cd65e7d91a2580ea4a3c047&quot;,
#                 {
#                     center: [47.48141835, 19.13001575],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0a56108e6cd65e7d91a2580ea4a3c047);
#
#
#
#
#
#             var tile_layer_932f37c32b57e1b3ddc597b1a9f70d30 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_932f37c32b57e1b3ddc597b1a9f70d30.addTo(map_0a56108e6cd65e7d91a2580ea4a3c047);
#
#
#             var feature_group_eb938575422d428f437ec3d460e74074 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_5f7cc5e0a13ddfa9e624fe50037cfb97_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#ffffff&quot;, &quot;fillColor&quot;: &quot;#ffffff&quot;, &quot;fillOpacity&quot;: 0.15, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_5f7cc5e0a13ddfa9e624fe50037cfb97_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_5f7cc5e0a13ddfa9e624fe50037cfb97 = L.geoJson(null, {
#                 onEachFeature: geo_json_5f7cc5e0a13ddfa9e624fe50037cfb97_onEachFeature,
#
#                 style: geo_json_5f7cc5e0a13ddfa9e624fe50037cfb97_styler,
#             ...{
# }
#         });
#
#         function geo_json_5f7cc5e0a13ddfa9e624fe50037cfb97_add (data) {
#             geo_json_5f7cc5e0a13ddfa9e624fe50037cfb